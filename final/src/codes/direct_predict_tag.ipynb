# %%
# TODO: Remove this
# https://www.kaggle.com/sudalairajkumar/transfer-learning-on-stack-exchange-tags/frequent-words-model-v3/code

# %%
import pandas as pd
import numpy as np
import re
from bs4 import BeautifulSoup
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from nltk import FreqDist
from nltk.corpus import brown

tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
stops = set(stopwords.words("english"))
frequency_list = FreqDist(i.lower() for i in brown.words())

# %%
len(stops)
# Out:
# 153

# %%
DATA_FOLDER = 'data/'
TRAIN_FILES = ['biology.csv', 'cooking.csv', 'crypto.csv', 'diy.csv', 'robotics.csv', 'travel.csv']
TEST_FILE = 'test.csv'

# %%
DOMAIN_COUNT = len(TRAIN_FILES)

# %% [markdown]
# # Load Data

# %%
df_trains = [pd.read_csv(DATA_FOLDER + filename) for filename in TRAIN_FILES]

# %%
for df in df_trains:
    print(df.shape)
# Out:
# (13196, 4)
# (15404, 4)
# (10432, 4)
# (25918, 4)
# (2771, 4)
# (19279, 4)

# %%
sum([df.shape[0] for df in df_trains])
# Out:
# 87000

# %%
df_trains[0].head()
# Out:
#    id                                              title  \
# 0   1  What is the criticality of the ribosome bindin...
# 1   2  How is RNAse contamination in RNA based experi...
# 2   3      Are lymphocyte sizes clustered in two groups?
# 3   4  How long does antibiotic-dosed LB maintain goo...
# 4   5        Is exon order always preserved in splicing?
#
#                                              content  \
# 0  <p>In prokaryotic translation, how critical fo...
# 1  <p>Does anyone have any suggestions to prevent...
# 2  <p>Tortora writes in <em>Principles of Anatomy...
# 3  <p>Various people in our lab will prepare a li...
# 4  <p>Are there any cases in which the splicing m...
#
#                                                 tags
# 0  ribosome binding-sites translation synthetic-b...
# 1                                   rna biochemistry
# 2                 immunology cell-biology hematology
# 3                                       cell-culture
# 4            splicing mrna spliceosome introns exons

# %%
train_tags = df_trains[0]['tags'].tolist()
train_tags[:20]
# Out:
# ['ribosome binding-sites translation synthetic-biology',
#  'rna biochemistry',
#  'immunology cell-biology hematology',
#  'cell-culture',
#  'splicing mrna spliceosome introns exons',
#  'dna biochemistry molecular-biology',
#  'neuroscience synapses',
#  'plasmids',
#  'molecular-genetics gene-expression experimental-design',
#  'evolution mitochondria chloroplasts',
#  'high-throughput cell-based',
#  'molecular-biology synthetic-biology',
#  'bioinformatics homework',
#  'neuroscience immunology',
#  'splicing histone',
#  'genomics gene-annotation exons',
#  'microbiology virology influenza',
#  'epigenetics',
#  'molecular-biology dna-isolation',
#  'cell-membrane adaptation cell-biology']

# %%
df_test = pd.read_csv(DATA_FOLDER + TEST_FILE)
print(df_test.shape)
df_test.head(10)
# Out:
# (81926, 3)
#    id                                              title  \
# 0   1  What is spin as it relates to subatomic partic...
# 1   2  What is your simplest explanation of the strin...
# 2   3   Lie theory, Representations and particle physics
# 3   7                 Will Determinism be ever possible?
# 4   9                               Hamilton's Principle
# 5  13              What is sound and how is it produced?
# 6  15      What experiment would disprove string theory?
# 7  17  Why does the sky change color? Why the sky is ...
# 8  19  How's the energy of particle collisions calcul...
# 9  21                                    Monte Carlo use
#
#                                              content
# 0  <p>I often hear about subatomic particles havi...
# 1  <p>How would you explain string theory to non ...
# 2  <p>This is a question that has been posted at ...
# 3  <p>What are the main problems that we need to ...
# 4  <p>Hamilton's principle states that a dynamic ...
# 5  <p>I've been using the term "sound" all my lif...
# 6  <p>I know that there's big controversy between...
# 7  <p>Why does the sky change color? Why the sky ...
# 8  <p>Physicists often refer to the energy of col...
# 9  <p>Where is the Monte Carlo method used in phy...

# %% [markdown]
# # Cleanse Data

# %%
commmon_words = set()
for word, frequent in frequency_list.most_common()[:20000]:
    commmon_words.add(word)

wrong_tags = set(('edit update dont thats video videos btw tricky'
+ ' google googling websites website online wiki wikipedia internet'
+ ' homework exam arxiv stackexchange cancelled basics approx'
+ ' beginner colour colours bike bicycle textbooks info youtube com'
+ ' whats pdf physicist physicists mathematician mathematicians ref').split())
    
useless_words = commmon_words | stops | wrong_tags
print(len(useless_words))
# Out:
# 20054

# %%
# remove [n]
# remove pure numbers, don't remove letter+number words, like CO2

# remove stopwords
# consider µL?
# remove formulas


numbers = set('0123456789-')

def is_useful_word(word):
    return (word not in useless_words) and (len(word) > 2) and (re.search('[a-z]', word)) and (word[0] not in numbers)
    

def cleanse_html(content):
    content = BeautifulSoup(content, "lxml").get_text()

    # remove urls
    content = re.sub(r"\S+:/\S+","", content)  # "xxx:/xxx"
    content = re.sub(r"\S+\\\S+","", content)  # "xxx\xxx"
    
    return content
    

def cleanse_lower_split(content):
    # remove html tags
    content = BeautifulSoup(content, "lxml").get_text()
    
    # remove urls
    content = re.sub(r"\S+:/\S+","", content)  # "xxx:/xxx"
    content = re.sub(r"\S+\\\S+","", content)  # "xxx\xxx"
    
    # replace punctuations and numbers with whitespaces
    content = re.sub(r"[^a-zA-Z0-9\-]"," ", content)
        
    # convert to lowercase
    content = content.lower()
    
    words = content.split()
    
    # remove useless words
    # stopwords, pure numbers, short words
    words = [word for word in words if is_useful_word(word)]
    
    return words

# only reserve words.
def cleanse(content):
    # remove html tags
    content = BeautifulSoup(content, "lxml").get_text()
    
    # remove urls
    content = re.sub(r"\S+:/\S+","", content)  # "xxx:/xxx"
    content = re.sub(r"\S+\\\S+","", content)  # "xxx\xxx"
    
    # replace punctuations and numbers with whitespaces
    content = re.sub(r"[^a-zA-Z0-9\-]"," ", content)
        
    # convert to lowercase
    content = content.lower()
    
    words = content.split()
    
    # remove useless words
    # stopwords, pure numbers, short words
    words = [word for word in words if is_useful_word(word)]
    
    # concat words to a string
    content = ' '.join(words)
    
    return content

# %%
def cleanse_contents_of_df(df):
    contents = df['content'].tolist()
    cleansed_contents = [cleanse(content) for content in contents]
    return cleansed_contents

def cleanse_titles_of_df(df):
    contents = df['title'].tolist()
    cleansed_contents = [cleanse(content) for content in contents]
    return cleansed_contents

def cleanse_strings(strList):
    cleansed = [cleanse(s) for s in strList]
    return cleansed

# %% [markdown]
# # Predict Tags

# %%
def predict_tags_from_cleansed_contents(cleansed_contents, max_features):
    vectorizer = TfidfVectorizer(use_idf=False, \
                                 stop_words = "english", \
                                 tokenizer = str.split,    \
                                 preprocessor = None, \
                                 max_features = max_features)
    features = vectorizer.fit_transform(cleansed_contents)
    feature_words = vectorizer.get_feature_names()
    
    predicted_tags = []

    for feature in features:
        values = feature.data
        _, word_idxs = feature.nonzero()

        index_sorted = np.argsort(values)[::-1]
        keywords = [feature_words[wid] for wid in word_idxs[index_sorted]]
        predicted_tags.append(' '.join(keywords))
    
    return predicted_tags

# %% [markdown]
# # Experiments - Train

# %%
# train_0_cleansed_contents = cleanse_contents_of_df(df_trains[0])

# %%
# train_0_predicted_tags = predict_tags_from_cleansed_contents(train_0_cleansed_contents, max_features=1000)

# %%
# train_0_predicted_tags[:30]

# %%
# train_0_tags = df_trains[0]['tags'].tolist()
# train_0_tags[:30]

# %% [markdown]
# # Prepare data

# %%
test_contents = df_test['content'].tolist()
test_titles = df_test['title'].tolist()
test_titles_contents = (df_test['title'] + ' ' + df_test['content']).tolist()

# %% [markdown]
# # Contents

# %%
test_cleansed_contents = cleanse_contents_of_df(df_test)

# %%
test_predicted_tags = predict_tags_from_cleansed_contents(test_cleansed_contents, max_features=2000)

# %%
test_predicted_tags_noun = []

for tags in test_predicted_tags:
    pos_tagged = nltk.pos_tag(tags.split())
    noun_tags = [i[0] for i in pos_tagged if i[1][0] in "N"]
    noun_tags_str = ' '.join(noun_tags)
    test_predicted_tags_noun.append(noun_tags_str)

# %%
test_predicted_tags_noun[:1000]

# %%
pos_tagged = nltk.pos_tag('gravitational'.split())
print(pos_tagged)
noun_tags = [i[0] for i in pos_tagged if i[1][0] in "N"]
print(noun_tags)

# %%
test_predicted_tags[:2000]

# %% [markdown]
# # Titles

# %%
test_cleansed_titles = cleanse_titles_of_df(df_test)

# %%
test_predicted_tags = predict_tags_from_cleansed_contents(test_cleansed_titles, max_features=2000)

# %%
test_predicted_tags_noun = []

for tags in test_predicted_tags:
    pos_tagged = nltk.pos_tag(tags.split())
    noun_tags = [i[0] for i in pos_tagged if i[1][0] in "N"]
    noun_tags_str = ' '.join(noun_tags)
    test_predicted_tags_noun.append(noun_tags_str)

# %%
test_predicted_tags_noun[:2000]

# %% [markdown]
# # Title + Content

# %%
test_cleansed_titles_contents = cleanse_strings(test_titles_contents)

# %%
test_predicted_tags = predict_tags_from_cleansed_contents(test_cleansed_titles_contents, max_features=1000)

test_predicted_tags_noun = []

for tags in test_predicted_tags:
    pos_tagged = nltk.pos_tag(tags.split())
    noun_tags = [i[0] for i in pos_tagged if i[1][0] in "N"]
    noun_tags_str = ' '.join(noun_tags)
    test_predicted_tags_noun.append(noun_tags_str)

# %%
test_predicted_tags_noun[:2000]
# Out:
# ['',
#  '',
#  '',
#  'laplace',
#  '',
#  '',
#  'disprove',
#  '',
#  'collisions higgs boson',
#  'carlo',
#  '',
#  'projectile gauss',
#  'collapses interacts',
#  '',
#  '',
#  'coriolis rotate',
#  'magnets',
#  '',
#  'qft invariants manifolds topology',
#  '',
#  'magnets',
#  'lhc',
#  '',
#  'laser lasers',
#  '',
#  '',
#  '',
#  'neutrons',
#  'entanglement photons',
#  'laser photon poisson',
#  'neutron',
#  'tensor approximations',
#  'emit',
#  'coulomb integrating',
#  'laser polarizations poincar',
#  'cosmological',
#  'isotope mev isotopes',
#  'neutron',
#  'collider collides',
#  'centripetal',
#  'formalism',
#  'mathematica',
#  'photons',
#  '',
#  'mathematica graphs',
#  'higgs boson lhc',
#  'neutrons boson fermions',
#  'neutrinos',
#  'navier-stokes',
#  '',
#  '',
#  'rightarrow',
#  '',
#  '',
#  'projectile calculus algebra',
#  'anti-matter',
#  'gauss convection',
#  'compress',
#  '',
#  'boson collisions luminosity quark',
#  'propeller',
#  '',
#  'manifolds topology algebras',
#  'causality scenarios scenario',
#  'photons',
#  'neutrons quarks macroscopic',
#  'transformations',
#  'frac rightarrow converting radiates',
#  '',
#  '',
#  '',
#  'software mathematica',
#  'gyroscope simulation simulating undergoes pointers',
#  '',
#  'positron antimatter',
#  '',
#  '',
#  'many-body qft approximations wavefunction perturbation schrodinger',
#  'gev',
#  '',
#  '',
#  'absorbs',
#  'precession outwards',
#  '',
#  'rotations',
#  'bernoulli',
#  '',
#  'convection',
#  '',
#  '',
#  'photoelectric',
#  'higgs lepton',
#  'randomness eigenvalue penrose',
#  'centripetal',
#  '',
#  '',
#  'precession gyroscope rad',
#  '',
#  'refraction',
#  'convex',
#  'phd',
#  'volts',
#  '',
#  '',
#  '',
#  'astronauts invariance',
#  '',
#  'torus',
#  'lhc',
#  'ellipse approximations newtons',
#  'emit optics blackbody',
#  'coriolis',
#  'impedance refraction optics',
#  'eigenfunctions eigenvalues eigenvalue',
#  'space-time',
#  'collisions nucleon',
#  'dirac positrons formalism positron valence semiconductors unsure',
#  'backwards asymmetry antimatter',
#  'software',
#  'astronomers',
#  'astronomers',
#  'algebra',
#  'vec cdot',
#  '',
#  'collisions photons',
#  'x-axis',
#  'gravitons photons',
#  'polarizations optics',
#  'frac phi cauchy',
#  'photon wavefunction dirac dinger massless',
#  'scenario scenarios',
#  'z-axis',
#  'simulation electrostatics electrodynamics',
#  'frac',
#  'astronomers',
#  '',
#  'photons',
#  'electromagnet transmit electromagnetism',
#  'lattice interacting spins',
#  'recombination photon',
#  'isotropic',
#  '',
#  'cdot mathbf',
#  'integrals',
#  'perpendicular',
#  'transformations',
#  '',
#  '',
#  'neutrons collide semiconductor',
#  'neutron microwave',
#  'phys',
#  'microwave',
#  'absorbs',
#  'mathrm',
#  '',
#  'macroscopic nonzero microstates fluctuations',
#  'cut-off',
#  '',
#  '',
#  'lasers laser',
#  'neutron',
#  '',
#  '',
#  'coulomb electrostatics electromagnetism',
#  'spacetime poisson cones',
#  '',
#  '',
#  '',
#  '',
#  'rotate stellar',
#  'centre asymmetric',
#  'planar graphs lattice matrix vertices',
#  'momenta',
#  '',
#  'macroscopic',
#  'photon photons compton micro pointer',
#  'quantization hilbert trajectories',
#  'backwards deceleration simulation compensate',
#  'laser coherence lasers',
#  'dirac',
#  '',
#  'frac sqrt leq collide vibrate kinematics',
#  '',
#  'iss',
#  '',
#  'propagate',
#  'asymmetry baryons',
#  '',
#  'singularity',
#  'tensor',
#  '',
#  'energy-momentum',
#  'evolves',
#  'grid magnets',
#  'frictionless trajectory',
#  'frictionless',
#  'schr dinger psi covariant',
#  'renormalization qft divergences',
#  'photon',
#  'cft',
#  'simulation',
#  '',
#  'mathbb',
#  '',
#  'earths',
#  'projectile software trajectory',
#  '',
#  'mev',
#  'inertia mgh',
#  'constraint ddot cos unsure lagrange qquad',
#  '',
#  '',
#  'precession',
#  'coherence wigner',
#  'photons duality hologram planck',
#  'quarks postulates',
#  '',
#  'unsure astronomers',
#  '',
#  'emit semiconductors',
#  'qubits',
#  'qft',
#  'fourier anyways',
#  'infinity',
#  'scenarios',
#  'photon mach',
#  'algebra quark mesons',
#  'photons emit joules',
#  '',
#  'transformations eigenfunctions integrals',
#  'calculus',
#  'boosts gut noether contradicts',
#  'euclidean',
#  'maths differentiate',
#  '',
#  'spacelike spacetime',
#  '',
#  '',
#  'algebra centre simplification convergence',
#  '',
#  'ftl',
#  'quantization interacts photons polarizations',
#  '',
#  'photons gravitons',
#  'electrostatics electrodynamics electromagnetism propto',
#  'imaging pixel',
#  '',
#  'singularity singularities',
#  'astronomers evaporate hawking evaporation',
#  'collisions',
#  'vortex vortices',
#  'collisions',
#  '',
#  '',
#  '',
#  'm-theory',
#  'varphi',
#  'cdot matrices',
#  '',
#  '',
#  '',
#  '',
#  'lattice photon computational',
#  'scenario cmb',
#  '',
#  '',
#  'lagrange rightarrow simulation behaves',
#  '',
#  'gps hawking',
#  'derivatives wavefunction',
#  'quantize quantization interact manifolds gravitons phonons moduli',
#  '',
#  'boltzmann',
#  'pauli fermions wave-function',
#  'higgs couplings yukawa',
#  '',
#  '',
#  '',
#  'laser photons phi',
#  'droplets',
#  'magnets',
#  'rangle psi optics photon qubits qubit',
#  'helicity chirality spins',
#  'causality electrodynamics renormalization disappears',
#  'coulomb infinity helmholtz vanishes curl',
#  '',
#  '',
#  '',
#  'collisions rotate spins',
#  'kinematics refraction',
#  'collisions pmatrix nonlinear',
#  'wavefunction wave-function superpositions',
#  'coriolis unsure deflection',
#  'coriolis newtons trajectory anti',
#  'sinusoidal',
#  '',
#  'antimatter asymmetry positron behaves',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'dilation',
#  'rotate centre rotates',
#  'macroscopic',
#  'teleportation',
#  'vortex sinusoidal oscillates',
#  'rightarrow hbar nabla',
#  'emergent tensor decoherence',
#  'decays',
#  '',
#  'singularity schwarzschild',
#  '',
#  'cartesian',
#  'electromagnetism',
#  'kilogram moles',
#  'converge',
#  '',
#  'cosine sinusoidal',
#  'chern torus conductance',
#  'electrodynamics simulations',
#  'coulomb invariance cdot electrodynamics',
#  'infty',
#  '',
#  '',
#  'frac rad const',
#  '',
#  'proofs prof',
#  '',
#  '',
#  'deceleration translational',
#  '',
#  '',
#  'doppler',
#  'co2',
#  'loops',
#  'photons propagates',
#  'space-time',
#  '',
#  'filament',
#  '',
#  'qft integrals klein-gordon',
#  '',
#  '',
#  'displacements electrodynamics nabla',
#  'rotate',
#  'propeller',
#  '',
#  '',
#  'align',
#  'photons superposition qed feynman propagators',
#  'calculates',
#  'coriolis centrifugal rotates',
#  'thermodynamics',
#  'photons optics graviton',
#  'interact teleportation',
#  'metre spacetime',
#  'spins divergence',
#  'divergence',
#  'magnets monopole',
#  'thermodynamics',
#  '',
#  '',
#  '',
#  'inductance',
#  'euler rho',
#  '',
#  'lattice lattices',
#  'neutrons isotopes',
#  '',
#  'derivatives',
#  '',
#  'downwards',
#  'astronomers cmb',
#  'invariance epsilon perpendicular neq',
#  'matrix qubits tensor hilbert matrices oscillator',
#  '',
#  '',
#  'matrix algebras eigenvalues matrices',
#  'hilbert analog',
#  'refraction',
#  '',
#  'undergrad',
#  'frac harmonics',
#  'quark quarks',
#  'isotope',
#  'photons doppler heisenberg',
#  'quarks neutrons quark',
#  'eigenfunctions harmonics eigenvalues euclidean spinors',
#  'z-axis rotate phi psi',
#  '',
#  'optics electrodynamics susceptibility symmetries graviton mathbf lorentzian',
#  'reversal',
#  '',
#  'planck',
#  '',
#  'neutrons',
#  'broglie mev',
#  'matrix grid',
#  'mathbf epsilon cdot frac',
#  'planck dilation',
#  '',
#  '',
#  'computations',
#  'topology algebraic invariants',
#  'galactic',
#  'photon emits',
#  'approximations',
#  'singularity',
#  '',
#  'derivatives',
#  '',
#  '',
#  '',
#  'droplets',
#  '',
#  'droplets emits',
#  'lattice neutron coulomb tesla orbitals',
#  '',
#  'centrifugal',
#  'coulomb frac varepsilon',
#  '',
#  'thermodynamics',
#  'centre',
#  'euler-lagrange scalar',
#  '',
#  'anyways maths blog',
#  'reversal invariance',
#  '',
#  'propagate',
#  'dioxide celsius',
#  'phonons photons phonon graphs semiconductors',
#  'laser excitation optics',
#  'phonons',
#  'isotope isotopes scatter',
#  'repulsion coulomb dipoles',
#  'capacitor tesla',
#  '',
#  'electrodynamics electromagnetism yang-mills',
#  'eigenstates photons eigenstate',
#  'rightarrow fermi mbox perturbation eigenstate',
#  '',
#  '',
#  'vibrate',
#  '',
#  'spacetime topology lorentz',
#  'emf',
#  'emf',
#  '',
#  'superconductivity',
#  'cft rangle langle prod',
#  'inertia interact cutoff',
#  '',
#  'asteroids asteroid',
#  'photon radiate',
#  'newtons time-reversal',
#  '',
#  'celsius',
#  'quark qcd',
#  'electromagnetism',
#  'pointers collide colliding',
#  'qft lattice',
#  'mach capacitor resistive',
#  '',
#  'graphs algebra',
#  'divergences renormalization',
#  '',
#  '',
#  'graphs',
#  '',
#  'integrals renormalization',
#  'photons',
#  'evaporate hawking',
#  'rangle langle single-particle tensor diverge',
#  'eclipse',
#  '',
#  'photon interacts raman',
#  '',
#  'singularity cauchy',
#  '',
#  'simulation interact',
#  '',
#  'cube frictionless',
#  '',
#  'celsius kilometers',
#  'spins degenerate rotate',
#  'scatter',
#  'transmit',
#  '',
#  '',
#  'fourier',
#  'magnetization rightarrow simulation lattice graviton obtains analogue',
#  '',
#  'vec cdot',
#  '',
#  '',
#  'optics',
#  'refraction',
#  '',
#  'photons',
#  'sigma rangle qubits matrices mathematica matrix langle qubit rho thermodynamic',
#  'optics conformal isotropy geodesics trajectories isotropic electrodynamics refraction jumps',
#  '',
#  '',
#  'cft qft duality qcd aka',
#  '',
#  'electromagnet magnets',
#  '',
#  'collider supersymmetry hadron',
#  'optics photons electrodynamics qed',
#  'algebras neumann',
#  '',
#  'quark quarks qcd higgs yukawa converge leptons perturbative',
#  'optics photons electrodynamics schroedinger',
#  '',
#  '',
#  'packets thermodynamics',
#  '',
#  '',
#  'inconsistency matrix postulates decoherence blackhole',
#  '',
#  'grid nodes',
#  'schrodinger eigenfunctions',
#  'laser lasers',
#  'propagating',
#  'eigenfunctions nodes',
#  '',
#  '',
#  'expands',
#  'inertia evaporation thermodynamic',
#  '',
#  '',
#  'oscillations',
#  'isotropic propagate behaves hooke',
#  '',
#  'integrals',
#  '',
#  'cartesian',
#  'laser coherence',
#  '',
#  'radiate pulses',
#  'valve temp',
#  '',
#  'lbs',
#  '',
#  'magnets scenario',
#  'photons scenario bends',
#  'collisions',
#  'photons scenario',
#  '',
#  'computations',
#  'photon kev',
#  'telescopes',
#  'capacitors simplification capacitor',
#  'optics',
#  'lattice repulsion',
#  'integrals',
#  'telescopes',
#  'lhc',
#  'pointers',
#  'epr',
#  'nucleons computations orbitals pions',
#  'axioms mit',
#  'densities',
#  'quarks',
#  'photons massless',
#  'galilean',
#  '',
#  'universes',
#  'photons scenario pions excitations',
#  'conductors',
#  'resistor',
#  'repulsion qft photons',
#  'der',
#  'milky',
#  'fermions precession spacetime incorporate',
#  'quadrupole',
#  '',
#  'singularity',
#  'singularity oscillate',
#  '',
#  'spins',
#  'trajectory',
#  '',
#  'galileo approximations incorporate kepler weinberg corrections',
#  '',
#  '',
#  'optics',
#  'inputs sinusoidal',
#  'spacetime',
#  '',
#  'tesla',
#  '',
#  '',
#  'kinematics',
#  'convection conduction',
#  'transformations',
#  '',
#  'universes',
#  '',
#  'infinity',
#  'expands',
#  '',
#  'torques tensors',
#  'antimatter positron',
#  '',
#  'epr randomness disprove',
#  '',
#  '',
#  '',
#  '',
#  'optics',
#  'loops nodes',
#  '',
#  'superconductor superconducting superconductors',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'hilbert vertices constraints dirac simplifies diffeomorphism',
#  '',
#  'frac12 mathrm software solves',
#  'simulation maths',
#  'tensor ricci riemann christoffel',
#  '',
#  'cones',
#  'blackhole',
#  'backwards multiverse',
#  'metres',
#  'neutron',
#  '',
#  '',
#  '',
#  '',
#  'neutrons',
#  '',
#  '',
#  'tidal',
#  '',
#  'photons optics phonons',
#  '',
#  '',
#  'resistor gauss vec dielectric',
#  '',
#  'manifolds proofs',
#  '',
#  'anyways',
#  'software',
#  '',
#  '',
#  'rotational',
#  'confuses',
#  'scenarios',
#  'infinity superconductors resistivity',
#  '',
#  'emits lasers',
#  'lasers',
#  'evaporation condensate',
#  '',
#  'fermions wavefunction pauli',
#  'electrodynamics renormalization on-shell',
#  'cft polyakov qft supergravity',
#  'renormalization conformal electrodynamics',
#  'scenarios',
#  'proportionality nodes',
#  'excitations boltzmann',
#  'thermodynamics',
#  'quarks neutrinos leptons muons collisions pointers bonus',
#  '',
#  'lambda',
#  'overline rho modulus tensor cdot pmatrix displacements',
#  'hilbert oscillator fock bosons dinger quantization annihilate observables hamiltonians',
#  'thermodynamics',
#  'lattice eigenvalue plugging bloch',
#  '',
#  'evaporate prof',
#  'grid',
#  'inertia galileo',
#  'thermodynamics',
#  'mathbf determinant nonzero constraint excitations constraints',
#  '',
#  '',
#  'hamiltonian qed',
#  'centrifugal spins',
#  'transformations wavefunction spacetime psi observables parity',
#  '',
#  'blackbody radiate temp',
#  'schwarzschild',
#  'scenarios',
#  'isotropic',
#  'invariance noether',
#  'thermodynamics',
#  'emit evaporate vanishes',
#  'microwaves',
#  'electrodynamics',
#  'rho rangle geq psi schr dinger rotational',
#  'condensate bose-einstein',
#  'laser',
#  'spacetime',
#  '',
#  'quark simplification annihilate antiparticle',
#  'positron positrons photons fermi bounces',
#  'invariance noether',
#  '',
#  'quarks baryons deflection collisions mesons',
#  'graphs infinity options',
#  'evaporate hawking',
#  'deceleration',
#  'qcd pointers',
#  'matrix adjoint',
#  'slits',
#  'qquad quad theta subtract',
#  'cartesian',
#  'coherence oscillating',
#  '',
#  'sigma matrix pmatrix covariance bmatrix',
#  'interacting',
#  'rotate rad cmb milky helicopter',
#  'lattice convex exp lambda massless',
#  'wavefunction quarks orbitals wavefunctions',
#  '',
#  'slits interact',
#  'refraction',
#  '',
#  'photons',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'frictionless',
#  'orbitals',
#  'spacetime maths wormholes dilation minkowski spacelike manifolds diffeomorphism variance timelike analogue obtains infinity asymmetry undergoes transformations scenario contradictory',
#  'deuterium dyson',
#  'manifolds',
#  'photons interacting',
#  'impedance dielectric',
#  'gps galileo',
#  'centre milky',
#  'neutron joules',
#  'excitation',
#  'magnets software scenarios',
#  'centre noether',
#  'boosts',
#  'photons',
#  'conduction semiconductor photons valence silicon',
#  '',
#  'boltzmann formalism computational',
#  '',
#  'lepton neutrinos mass-energy',
#  'yang-mills',
#  'higgs',
#  'valence superposition superconductors',
#  'phonons phonon matrix plugging hbar vanishes infinity lattice perturbation fourier algebra int',
#  '',
#  'transformations',
#  'positron reversal symmetries parity conjugation',
#  'isotropic geodesics',
#  'singularity geodesics hypersurface',
#  'formalism graphs feynman riemann',
#  'lattice gaps',
#  'neutrinos asymmetry cmb annihilate',
#  'tensor derivatives schroeder',
#  'apologize bends',
#  'thermodynamics learnt',
#  'eigenstates quarks matrices leptons',
#  'compress scenario',
#  'lattice heats',
#  'harmonic',
#  'higgs boson',
#  'rightarrow quanta spacetime mapsto',
#  'collide singularities interact',
#  'photons',
#  'matrix centre brillouin',
#  '',
#  'recombination cmb',
#  '',
#  'photon photons',
#  'emit',
#  'psi',
#  'non-zero',
#  'hbar planck',
#  'neutron',
#  'formalism renormalization amplitudes',
#  'decoherence planck',
#  'singularity singularities',
#  '',
#  'qft spacetime matrix matrices',
#  'perturbation hamiltonian scenario',
#  'fluctuations',
#  'rotate',
#  'insulator',
#  'rotate optics',
#  '',
#  'photon photons microwaves',
#  '',
#  '',
#  'amplitudes yang-mills momenta gluons',
#  '',
#  'frac',
#  'photon photons droplet superfluid',
#  'entanglement',
#  'photons',
#  '',
#  'coherence decoherence photon',
#  'algebra pauli rotate dirac matrices',
#  'collapses interacts decoherence superposition',
#  'invariance vanishes regularization',
#  '',
#  'accelerations microwaves',
#  'compress',
#  'eigenstates spins normalization',
#  'polymer quantify constraints',
#  '',
#  'radiative',
#  '',
#  '',
#  'excitation canonical',
#  '',
#  'estimating',
#  'vortex',
#  'phys multiverse',
#  'neutron pauli radiate',
#  '',
#  'photons collisions cmb',
#  'quantization undergoes vertices',
#  'blackbody',
#  'vortex invariants couplings insulators',
#  'collisions',
#  'metres',
#  'space-time',
#  'gut',
#  '',
#  'lattice graphene',
#  'disappears conductors',
#  'oscillations',
#  'macroscopic schrodinger oscillator superposition slits',
#  'neutrinos',
#  '',
#  '',
#  'renormalization peskin schroeder',
#  '',
#  'photons emits slits',
#  'optics outwards telescopes',
#  'rotate perpendicular spins',
#  'space-time',
#  'branes anomalies transformations',
#  '',
#  'simulation',
#  'scenario',
#  'telescopes infer',
#  'graphene fermions lattice interacting obtains excitations',
#  'photon orbital tunneling',
#  'teleportation',
#  'module',
#  'formalism der generic',
#  'scenarios',
#  '',
#  'gauss microwaves',
#  'algorithm',
#  'higgs perturbation massless renormalized',
#  '',
#  'perpendicular spinors',
#  'solves accelerations',
#  'collisions',
#  'decoherence photons algorithm',
#  'variance commutes',
#  'kilogram',
#  'cft dimensionless lhs',
#  'centre trajectory singularities',
#  '',
#  'formalism perturbation',
#  'photon photons',
#  '',
#  'algebra hilbert excitation branes',
#  'lhc tev',
#  'universes',
#  'teleportation',
#  'laser pointer align',
#  'entanglement',
#  'decoherence wavefunction eigenstate probabilistic',
#  'qft',
#  'nodes simulation resistor cables',
#  'photons photon converting',
#  'quantization symmetries',
#  'phi',
#  'collisions valence filament excitation',
#  '',
#  'cft',
#  'feynman',
#  '',
#  'photon macroscopic packets metres',
#  'frac',
#  'photon disprove photons vibrations',
#  'branes scalar',
#  'oscillators',
#  'photons emit',
#  '',
#  'lorentz',
#  'entanglement timelike',
#  'photons photon macroscopic capacitor',
#  'mass-energy',
#  'observables eigenvalues universes constraints',
#  '',
#  'microwave',
#  '',
#  '',
#  '',
#  'coulomb monopoles',
#  'many-body graphene equiv',
#  'momenta quark phys landau int spin-orbit gluon',
#  'quantization radiate minima electrodynamics superposition int bohr goldstein',
#  'supergravity supersymmetry perturbative',
#  'photon',
#  'supersymmetry',
#  'sigma constraint fibre',
#  'topology anti-matter centre constraint timelike constraints',
#  '',
#  '',
#  '',
#  'randomly',
#  'minkowski diverges',
#  'superposition',
#  'infinity concentric',
#  'singularity singularities evaporation hawking',
#  '',
#  'coulomb electrostatics',
#  'algebra algebraic axioms gauss calculus proofs displacements',
#  'lattice polymer',
#  'excitations branes',
#  'matrix quark interacts emits neutrino',
#  '',
#  'semiconductors excitation conduction',
#  '',
#  'tensor riemann ricci weyl neutron poisson scenario nonzero phi accelerations',
#  'laser',
#  'insulators insulator',
#  '',
#  '',
#  '',
#  'compactification vibrations electromagnetism infer',
#  'higgs graphs',
#  'photon qubit photons',
#  'entanglement',
#  '',
#  '',
#  'topology non-zero',
#  '',
#  '',
#  'lhc',
#  'absorbs temp pde matlab',
#  'deceleration frictionless',
#  '',
#  '',
#  'laser photon',
#  '',
#  'asymmetry gev sigma quark feynman hadron gluons',
#  'simulation euler-lagrange',
#  'algorithm',
#  '',
#  'bracket dirac constraints commutator frac integrals quantization int poisson constraint formalism propto',
#  'decoherence superposition heisenberg',
#  'spaceship astronaut',
#  'causality violates',
#  'perturbations perturbation sqrt tensors',
#  'kelvin lattice',
#  'matrices',
#  'observables s-matrix',
#  'singularity singularities approximations spacelike theorems realise',
#  '',
#  'qft lagrangians',
#  'jumps',
#  'magnets',
#  'int',
#  'resistivity quantization rho sec localization',
#  'wavefunctions',
#  'rhs',
#  'laser',
#  'qft hamiltonian',
#  '',
#  'poincar one-particle',
#  '',
#  '',
#  'nasa',
#  'entanglement holographic',
#  'qft computations',
#  'rotate',
#  'rangle vert exp stern-gerlach kets',
#  'pauli substitution',
#  'metrics',
#  'simplification approximations',
#  'derivatives',
#  'droplet',
#  'refraction compensate',
#  'tensor hypersurface',
#  'renormalization qubit',
#  'invariance planck',
#  'vert algebras unitarity tensor nonzero cft vanishes ope',
#  'higgs collider astronomers hadron',
#  ...]

# %% [markdown]
# # Output

# %%
output_file_name = 'output/title-content_common20000_feature1000_noun.csv'

df_output = df_test[['id']]
df_output['tags'] = test_predicted_tags_noun
# Out:
# /home/roger/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_output.head(20)
# Out:
#     id                               tags
# 0    1
# 1    2
# 2    3
# 3    7                            laplace
# 4    9
# 5   13
# 6   15                           disprove
# 7   17
# 8   19             collisions higgs boson
# 9   21                              carlo
# 10  24
# 11  26                   projectile gauss
# 12  27                collapses interacts
# 13  29
# 14  31
# 15  32                    coriolis rotate
# 16  35                            magnets
# 17  37
# 18  41  qft invariants manifolds topology
# 19  49

# %%
import csv

df_output.to_csv(output_file_name, index=False, quoting=csv.QUOTE_NONNUMERIC)

# %% [markdown]
# # procedure
#
# * cleanse title and contents
# * apply tf idf
#
# ## try to guess if a word is a keyword
#
# * train the guess function with training data
# * input: tf, idf of title, content
#
# ## try to guess the tags of a post

# %%
# remove [n]
# remove pure numbers, don't remove letter+number words, like CO2
# remove urls

# %%
# tf-idf over all contents
# same-category contents concat as one doc

# %%
# for each tag, find words that mostly exist in title and contents of that tag
# use entropy to do the above thing
# if a test content contains words only exist in , then the content is very likely about that domain

# %%
# as classification problem
# features: bow (normalized)

# %%
# stop_words = {'a', "a's", 'able', 'about', 'above', 'according', 'accordingly',
#               'across', 'actually', 'after', 'afterwards', 'again', 'against',
#               "ain't", 'all', 'allow', 'allows', 'almost', 'alone', 'along',
#               'already', 'also', 'although', 'always', 'am', 'among', 'amongst',
#               'an', 'and', 'another', 'any', 'anybody', 'anyhow', 'anyone',
#               'anything', 'anyway', 'anyways', 'anywhere', 'apart', 'appear',
#               'appreciate', 'appropriate', 'are', "aren't", 'around', 'as',
#               'aside', 'ask', 'asking', 'associated', 'at', 'available', 'away',
#               'awfully', 'b', 'be', 'became', 'because', 'become', 'becomes',
#               'becoming', 'been', 'before', 'beforehand', 'behind', 'being',
#               'believe', 'below', 'beside', 'besides', 'best', 'better',
#               'between', 'beyond', 'both', 'brief', 'but', 'by', 'c', "c'mon",
#               "c's", 'came', 'can', "can't", 'cannot', 'cant', 'cause',
#               'causes', 'certain', 'certainly', 'changes', 'clearly', 'co',
#               'com', 'come', 'comes', 'concerning', 'consequently', 'consider',
#               'considering', 'contain', 'containing', 'contains',
#               'corresponding', 'could', "couldn't", 'course', 'currently', 'd',
#               'definitely', 'described', 'despite', 'did', "didn't",
#               'different', 'do', 'does', "doesn't", 'doing', "don't", 'done',
#               'down', 'downwards', 'during', 'e', 'each', 'edu', 'eg', 'eight',
#               'either', 'else', 'elsewhere', 'enough', 'entirely', 'especially',
#               'et', 'etc', 'even', 'ever', 'every', 'everybody', 'everyone',
#               'everything', 'everywhere', 'ex', 'exactly', 'example', 'except',
#               'f', 'far', 'few', 'fifth', 'first', 'five', 'followed',
#               'following', 'follows', 'for', 'former', 'formerly', 'forth',
#               'four', 'from', 'further', 'furthermore', 'g', 'get', 'gets',
#               'getting', 'given', 'gives', 'go', 'goes', 'going', 'gone', 'got',
#               'gotten', 'greetings', 'h', 'had', "hadn't", 'happens', 'hardly',
#               'has', "hasn't", 'have', "haven't", 'having', 'he', "he's",
#               'hello', 'help', 'hence', 'her', 'here', "here's", 'hereafter',
#               'hereby', 'herein', 'hereupon', 'hers', 'herself', 'hi', 'him',
#               'himself', 'his', 'hither', 'hopefully', 'how', 'howbeit',
#               'however', 'i', "i'd", "i'll", "i'm", "i've", 'ie', 'if',
#               'ignored', 'immediate', 'in', 'inasmuch', 'inc', 'indeed',
#               'indicate', 'indicated', 'indicates', 'inner', 'insofar',
#               'instead', 'into', 'inward', 'is', "isn't", 'it', "it'd", "it'll",
#               "it's", 'its', 'itself', 'j', 'just', 'k', 'keep', 'keeps',
#               'kept', 'know', 'knows', 'known', 'l', 'last', 'lately', 'later',
#               'latter', 'latterly', 'least', 'less', 'lest', 'let', "let's",
#               'like', 'liked', 'likely', 'little', 'look', 'looking', 'looks',
#               'ltd', 'm', 'mainly', 'many', 'may', 'maybe', 'me', 'mean',
#               'meanwhile', 'merely', 'might', 'more', 'moreover', 'most',
#               'mostly', 'much', 'must', 'my', 'myself', 'n', 'name', 'namely',
#               'nd', 'near', 'nearly', 'necessary', 'need', 'needs', 'neither',
#               'never', 'nevertheless', 'new', 'next', 'nine', 'no', 'nobody',
#               'non', 'none', 'noone', 'nor', 'normally', 'not', 'nothing',
#               'novel', 'now', 'nowhere', 'o', 'obviously', 'of', 'off', 'often',
#               'oh', 'ok', 'okay', 'old', 'on', 'once', 'one', 'ones', 'only',
#               'onto', 'or', 'other', 'others', 'otherwise', 'ought', 'our',
#               'ours', 'ourselves', 'out', 'outside', 'over', 'overall', 'own',
#               'p', 'particular', 'particularly', 'per', 'perhaps', 'placed',
#               'please', 'plus', 'possible', 'presumably', 'probably',
#               'provides', 'q', 'que', 'quite', 'qv', 'r', 'rather', 'rd', 're',
#               'really', 'reasonably', 'regarding', 'regardless', 'regards',
#               'relatively', 'respectively', 'right', 's', 'said', 'same', 'saw',
#               'say', 'saying', 'says', 'second', 'secondly', 'see', 'seeing',
#               'seem', 'seemed', 'seeming', 'seems', 'seen', 'self', 'selves',
#               'sensible', 'sent', 'serious', 'seriously', 'seven', 'several',
#               'shall', 'she', 'should', "shouldn't", 'since', 'six', 'so',
#               'some', 'somebody', 'somehow', 'someone', 'something', 'sometime',
#               'sometimes', 'somewhat', 'somewhere', 'soon', 'sorry',
#               'specified', 'specify', 'specifying', 'still', 'sub', 'such',
#               'sup', 'sure', 't', "t's", 'take', 'taken', 'tell', 'tends', 'th',
#               'than', 'thank', 'thanks', 'thanx', 'that', "that's", 'thats',
#               'the', 'their', 'theirs', 'them', 'themselves', 'then', 'thence',
#               'there', "there's", 'thereafter', 'thereby', 'therefore',
#               'therein', 'theres', 'thereupon', 'these', 'they', "they'd",
#               "they'll", "they're", "they've", 'think', 'third', 'this',
#               'thorough', 'thoroughly', 'those', 'though', 'three', 'through',
#               'throughout', 'thru', 'thus', 'to', 'together', 'too', 'took',
#               'toward', 'towards', 'tried', 'tries', 'truly', 'try', 'trying',
#               'twice', 'two', 'u', 'un', 'under', 'unfortunately', 'unless',
#               'unlikely', 'until', 'unto', 'up', 'upon', 'us', 'use', 'used',
#               'useful', 'uses', 'using', 'usually', 'uucp', 'v', 'value',
#               'various', 'very', 'via', 'viz', 'vs', 'w', 'want', 'wants',
#               'was', "wasn't", 'way', 'we', "we'd", "we'll", "we're", "we've",
#               'welcome', 'well', 'went', 'were', "weren't", 'what', "what's",
#               'whatever', 'when', 'whence', 'whenever', 'where', "where's",
#               'whereafter', 'whereas', 'whereby', 'wherein', 'whereupon',
#               'wherever', 'whether', 'which', 'while', 'whither', 'who',
#               "who's", 'whoever', 'whole', 'whom', 'whose', 'why', 'will',
#               'willing', 'wish', 'with', 'within', 'without', "won't", 'wonder',
#               'would', 'would', "wouldn't", 'x', 'y', 'yes', 'yet', 'you',
#               "you'd", "you'll", "you're", "you've", 'your', 'yours',
#               'yourself', 'yourselves', 'z', 'zero', ''}

# len(stop_words)

# %%
start = 30000
for word, frequent in frequency_list.most_common()[start:start + 2000]:
    print(word + ' ', end='')
